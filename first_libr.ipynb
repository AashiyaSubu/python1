# %%
from assignment_lib import assignment1

# %%
area,perimeter= assignment1.triangle()
print("Area:",area)
print("perimeter: ",perimeter)
assignment1.subfieldsinAI()
result=assignment1.oddeven()
assignment1.avrg()
assignment1.bmi1()
# Out:
# Enter the side1 width 5
# Enter the side2 width 5
# Enter the side3 width 5
# Area of a triangle is
# 12.5
# Perimeter of a triangle is
# 15
# Area: 12.5
# perimeter:  15
# Sub-fields in AI are:
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Natural Language Processin
# Enter the number 89
# Odd
# Enter the English mark 98
# Enter the Tamil mark 98
# Enter the Maths mark 78
# Enter the Science mark 85
# Enter the SST mark 98
# Enter the bmi:   52
# Obesity
# 'Obesity'
