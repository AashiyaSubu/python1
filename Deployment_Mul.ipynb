# %%
import pickle
loaded_model=pickle.load(open("Finalised_model_Mul_linear.sav",'rb'))

# %%
num1=float(input("Enter the R&DSpend"))
num2=float(input("Enter the Administration"))
num3=float(input("Enter the Marketing Spend"))
print("if city is Calofornia type 0 0,if city is FLorida type 1 0,if city is New York type 0 1")
num4=int(input("Enter the city"))
num5=int(input("Enter the city"))


result=loaded_model.predict([[num1,num2,num3,num4,num5]])
result
# Out:
# Enter the R&DSpend 0
# Enter the Administration 135429.56
# Enter the Marketing Spend 0
# if city is Calofornia type 0 0,if city is FLorida type 1 0,if city is New York type 0 1
# Enter the city 0
# Enter the city 0
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[46493.41244894]])
